# %%
# !pip install pyupbit
# Out:
# Requirement already satisfied: pyupbit in /usr/local/lib/python3.7/dist-packages (0.2.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pyupbit) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pyupbit) (1.1.5)
# Requirement already satisfied: pyjwt>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from pyupbit) (2.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pyupbit) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pyupbit) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pyupbit) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pyupbit) (2020.12.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pyupbit) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->pyupbit) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyupbit) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pyupbit) (1.15.0)

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup


coin_list = ["BTC", "MED", "MBL"]
time_units = ["days", "weeks"]
minutes_units = [1, 3, 5, 15, 30, 60, 240]
count = 400  # max : 400

for coin in coin_list:

    for time_unit in time_units:
        req = requests.get(
            f"https://crix-api-endpoint.upbit.com/v1/crix/candles/{time_unit}?code=CRIX.UPBIT.KRW-{coin}&count={count}"
        )
        data = req.json()
        result = []

        for i, candle in enumerate(data):
            result.append(
                {
                    "Time": data[i]["candleDateTimeKst"],
                    "OpeningPrice": data[i]["openingPrice"],
                    "HighPrice": data[i]["highPrice"],
                    "LowPrice": data[i]["lowPrice"],
                    "TradePrice": data[i]["tradePrice"],
                    "CandleAccTradeVolume": data[i]["candleAccTradeVolume"],
                    "candleAccTradePrice": data[i]["candleAccTradePrice"],
                }
            )

        coin_data = pd.DataFrame(result)
        coin_data.to_csv(f"{coin}_KRW_{time_unit}.csv")
    

    for minute_unit in minutes_units:
        req = requests.get(
            f"https://crix-api-endpoint.upbit.com/v1/crix/candles/minutes/{minute_unit}?code=CRIX.UPBIT.KRW-{coin}&count={count}"
        )
        data = req.json()
        result = []

        for i, candle in enumerate(data):
            result.append(
                {
                    "Time": data[i]["candleDateTimeKst"],
                    "OpeningPrice": data[i]["openingPrice"],
                    "HighPrice": data[i]["highPrice"],
                    "LowPrice": data[i]["lowPrice"],
                    "TradePrice": data[i]["tradePrice"],
                    "CandleAccTradeVolume": data[i]["candleAccTradeVolume"],
                    "candleAccTradePrice": data[i]["candleAccTradePrice"],
                }
            )
        
        coin_data = pd.DataFrame(result)
        coin_data.to_csv(f"{coin}_KRW_{minute_unit}.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
import datetime
import pyupbit

code = "KRW-BTC"

#df = pyupbit.get_ohlcv(code,interval='minute30',count=200)

# data = pd.read_csv('/content/MED_KRW_days.csv')
data_path = '/content/BTC_KRW_15_2021_2_26_0_16_31.csv'
INTERVAL = 'minute15'

data = pd.read_csv(data_path)
data = data.sort_values(by=['Time'], axis=0)


trade_prices = data["TradePrice"].values

# %%
seq_len = 30
sequence_length = seq_len + 1

result = []
for index in range(len(trade_prices) - sequence_length):
    result.append(trade_prices[index : index + sequence_length])


def normalize_windows(data):
    normalized_data = []
    for window in data:
        normalized_window = [((float(p) / float(window[0])) - 1) for p in window]
        # normalized_window = [((float(p) - min(window))/(max(window)-min(window))) for p in window]
        normalized_data.append(normalized_window)
    return np.array(normalized_data)


result = normalize_windows(result)
# result=np.array(result)

# split train and test data
row = int(round(result.shape[0] * 0.9))
train = result[:row, :]
np.random.shuffle(train)

x_train = train[:, :-1]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, -1]

x_test = result[row:, :-1]
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[row:, -1]

x_train.shape, x_test.shape
# Out:
# ((332, 30, 1), (37, 30, 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model = Sequential()

model.add(LSTM(seq_len, return_sequences=True, input_shape=(seq_len, 1)))

model.add(LSTM(64, return_sequences=True))
model.add(LSTM(32, return_sequences=False))

model.add(Dense(32, activation="linear"))
model.add(Dense(1, activation="linear"))



model.summary()

loss = Huber()
optimizer = Adam(0.0005)
model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 30, 30)            3840
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 30, 64)            24320
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 41,665
# Trainable params: 41,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
start_time = datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_%S")

model.fit(
    x_train,
    y_train,
    validation_data=(x_test, y_test),
    batch_size=64,
    epochs=100,
    callbacks=[
        TensorBoard(log_dir="logs/%s" % (start_time)),
        ModelCheckpoint(
            "./models/%s_eth.h5" % (start_time),
            monitor="val_loss",
            verbose=1,
            save_best_only=True,
            mode="auto",
        ),
        ReduceLROnPlateau(
            monitor="val_loss", factor=0.2, patience=5, verbose=0, mode="auto"
        ),
    ],
)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 5s 261ms/step - loss: 7.4995e-04 - mse: 0.0015 - val_loss: 1.5519e-04 - val_mse: 3.1038e-04
#
# Epoch 00001: val_loss improved from inf to 0.00016, saving model to ./models/2021_02_25_21_38_10_eth.h5
# Epoch 2/100
# 6/6 [==============================] - 0s 16ms/step - loss: 4.3188e-04 - mse: 8.6376e-04 - val_loss: 2.0888e-04 - val_mse: 4.1777e-04
#
# Epoch 00002: val_loss did not improve from 0.00016
# Epoch 3/100
# 6/6 [==============================] - 0s 19ms/step - loss: 2.8720e-04 - mse: 5.7440e-04 - val_loss: 1.4086e-04 - val_mse: 2.8172e-04
#
# Epoch 00003: val_loss improved from 0.00016 to 0.00014, saving model to ./models/2021_02_25_21_38_10_eth.h5
# Epoch 4/100
# 6/6 [==============================] - 0s 16ms/step - loss: 2.4903e-04 - mse: 4.9807e-04 - val_loss: 1.5442e-04 - val_mse: 3.0884e-04
#
# Epoch 00004: val_loss did not improve from 0.00014
# Epoch 5/100
# 6/6 [==============================] - 0s 16ms/step - loss: 2.2417e-04 - mse: 4.4835e-04 - val_loss: 1.4532e-04 - val_mse: 2.9065e-04
#
# Epoch 00005: val_loss did not improve from 0.00014
# Epoch 6/100
# 6/6 [==============================] - 0s 15ms/step - loss: 2.0934e-04 - mse: 4.1867e-04 - val_loss: 1.5097e-04 - val_mse: 3.0194e-04
#
# Epoch 00006: val_loss did not improve from 0.00014
# Epoch 7/100
# 6/6 [==============================] - 0s 15ms/step - loss: 2.0292e-04 - mse: 4.0584e-04 - val_loss: 1.4619e-04 - val_mse: 2.9238e-04
#
# Epoch 00007: val_loss did not improve from 0.00014
# Epoch 8/100
# 6/6 [==============================] - 0s 18ms/step - loss: 1.9836e-04 - mse: 3.9671e-04 - val_loss: 1.4344e-04 - val_mse: 2.8688e-04
#
# Epoch 00008: val_loss did not improve from 0.00014
# Epoch 9/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.9922e-04 - mse: 3.9844e-04 - val_loss: 1.3839e-04 - val_mse: 2.7677e-04
#
# Epoch 00009: val_loss improved from 0.00014 to 0.00014, saving model to ./models/2021_02_25_21_38_10_eth.h5
# Epoch 10/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.9331e-04 - mse: 3.8662e-04 - val_loss: 1.2650e-04 - val_mse: 2.5300e-04
#
# Epoch 00010: val_loss improved from 0.00014 to 0.00013, saving model to ./models/2021_02_25_21_38_10_eth.h5
# Epoch 11/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.9654e-04 - mse: 3.9309e-04 - val_loss: 1.3675e-04 - val_mse: 2.7349e-04
#
# Epoch 00011: val_loss did not improve from 0.00013
# Epoch 12/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8544e-04 - mse: 3.7087e-04 - val_loss: 1.3789e-04 - val_mse: 2.7577e-04
#
# Epoch 00012: val_loss did not improve from 0.00013
# Epoch 13/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8348e-04 - mse: 3.6697e-04 - val_loss: 1.3866e-04 - val_mse: 2.7733e-04
#
# Epoch 00013: val_loss did not improve from 0.00013
# Epoch 14/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8212e-04 - mse: 3.6425e-04 - val_loss: 1.3483e-04 - val_mse: 2.6966e-04
#
# Epoch 00014: val_loss did not improve from 0.00013
# Epoch 15/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8265e-04 - mse: 3.6530e-04 - val_loss: 1.3454e-04 - val_mse: 2.6909e-04
#
# Epoch 00015: val_loss did not improve from 0.00013
# Epoch 16/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9014e-04 - mse: 3.8029e-04 - val_loss: 1.3630e-04 - val_mse: 2.7261e-04
#
# Epoch 00016: val_loss did not improve from 0.00013
# Epoch 17/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9547e-04 - mse: 3.9095e-04 - val_loss: 1.3694e-04 - val_mse: 2.7388e-04
#
# Epoch 00017: val_loss did not improve from 0.00013
# Epoch 18/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9976e-04 - mse: 3.9953e-04 - val_loss: 1.3699e-04 - val_mse: 2.7398e-04
#
# Epoch 00018: val_loss did not improve from 0.00013
# Epoch 19/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8466e-04 - mse: 3.6932e-04 - val_loss: 1.3749e-04 - val_mse: 2.7499e-04
#
# Epoch 00019: val_loss did not improve from 0.00013
# Epoch 20/100
# 6/6 [==============================] - 0s 18ms/step - loss: 1.9624e-04 - mse: 3.9248e-04 - val_loss: 1.3826e-04 - val_mse: 2.7653e-04
#
# Epoch 00020: val_loss did not improve from 0.00013
# Epoch 21/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8772e-04 - mse: 3.7544e-04 - val_loss: 1.3859e-04 - val_mse: 2.7718e-04
#
# Epoch 00021: val_loss did not improve from 0.00013
# Epoch 22/100
# 6/6 [==============================] - 0s 15ms/step - loss: 2.0177e-04 - mse: 4.0354e-04 - val_loss: 1.3846e-04 - val_mse: 2.7692e-04
#
# Epoch 00022: val_loss did not improve from 0.00013
# Epoch 23/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9467e-04 - mse: 3.8934e-04 - val_loss: 1.3836e-04 - val_mse: 2.7671e-04
#
# Epoch 00023: val_loss did not improve from 0.00013
# Epoch 24/100
# 6/6 [==============================] - 0s 17ms/step - loss: 2.0145e-04 - mse: 4.0290e-04 - val_loss: 1.3841e-04 - val_mse: 2.7681e-04
#
# Epoch 00024: val_loss did not improve from 0.00013
# Epoch 25/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8141e-04 - mse: 3.6282e-04 - val_loss: 1.3834e-04 - val_mse: 2.7668e-04
#
# Epoch 00025: val_loss did not improve from 0.00013
# Epoch 26/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8364e-04 - mse: 3.6728e-04 - val_loss: 1.3823e-04 - val_mse: 2.7646e-04
#
# Epoch 00026: val_loss did not improve from 0.00013
# Epoch 27/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8813e-04 - mse: 3.7626e-04 - val_loss: 1.3822e-04 - val_mse: 2.7644e-04
#
# Epoch 00027: val_loss did not improve from 0.00013
# Epoch 28/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7617e-04 - mse: 3.5233e-04 - val_loss: 1.3818e-04 - val_mse: 2.7636e-04
#
# Epoch 00028: val_loss did not improve from 0.00013
# Epoch 29/100
# 6/6 [==============================] - 0s 18ms/step - loss: 2.0644e-04 - mse: 4.1288e-04 - val_loss: 1.3818e-04 - val_mse: 2.7635e-04
#
# Epoch 00029: val_loss did not improve from 0.00013
# Epoch 30/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8940e-04 - mse: 3.7880e-04 - val_loss: 1.3818e-04 - val_mse: 2.7635e-04
#
# Epoch 00030: val_loss did not improve from 0.00013
# Epoch 31/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.9203e-04 - mse: 3.8406e-04 - val_loss: 1.3818e-04 - val_mse: 2.7637e-04
#
# Epoch 00031: val_loss did not improve from 0.00013
# Epoch 32/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8819e-04 - mse: 3.7638e-04 - val_loss: 1.3818e-04 - val_mse: 2.7636e-04
#
# Epoch 00032: val_loss did not improve from 0.00013
# Epoch 33/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8156e-04 - mse: 3.6312e-04 - val_loss: 1.3818e-04 - val_mse: 2.7636e-04
#
# Epoch 00033: val_loss did not improve from 0.00013
# Epoch 34/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9220e-04 - mse: 3.8440e-04 - val_loss: 1.3819e-04 - val_mse: 2.7637e-04
#
# Epoch 00034: val_loss did not improve from 0.00013
# Epoch 35/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8154e-04 - mse: 3.6308e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00035: val_loss did not improve from 0.00013
# Epoch 36/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8684e-04 - mse: 3.7367e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00036: val_loss did not improve from 0.00013
# Epoch 37/100
# 6/6 [==============================] - 0s 16ms/step - loss: 2.1117e-04 - mse: 4.2234e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00037: val_loss did not improve from 0.00013
# Epoch 38/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9389e-04 - mse: 3.8778e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00038: val_loss did not improve from 0.00013
# Epoch 39/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8310e-04 - mse: 3.6619e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00039: val_loss did not improve from 0.00013
# Epoch 40/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8886e-04 - mse: 3.7771e-04 - val_loss: 1.3819e-04 - val_mse: 2.7637e-04
#
# Epoch 00040: val_loss did not improve from 0.00013
# Epoch 41/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9541e-04 - mse: 3.9083e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00041: val_loss did not improve from 0.00013
# Epoch 42/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9777e-04 - mse: 3.9554e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00042: val_loss did not improve from 0.00013
# Epoch 43/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9235e-04 - mse: 3.8470e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00043: val_loss did not improve from 0.00013
# Epoch 44/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.7412e-04 - mse: 3.4824e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00044: val_loss did not improve from 0.00013
# Epoch 45/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8731e-04 - mse: 3.7463e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00045: val_loss did not improve from 0.00013
# Epoch 46/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9378e-04 - mse: 3.8756e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00046: val_loss did not improve from 0.00013
# Epoch 47/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9400e-04 - mse: 3.8800e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00047: val_loss did not improve from 0.00013
# Epoch 48/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9163e-04 - mse: 3.8327e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00048: val_loss did not improve from 0.00013
# Epoch 49/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9077e-04 - mse: 3.8153e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00049: val_loss did not improve from 0.00013
# Epoch 50/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8706e-04 - mse: 3.7413e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00050: val_loss did not improve from 0.00013
# Epoch 51/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8806e-04 - mse: 3.7611e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00051: val_loss did not improve from 0.00013
# Epoch 52/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8520e-04 - mse: 3.7040e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00052: val_loss did not improve from 0.00013
# Epoch 53/100
# 6/6 [==============================] - 0s 16ms/step - loss: 2.0228e-04 - mse: 4.0456e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00053: val_loss did not improve from 0.00013
# Epoch 54/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9024e-04 - mse: 3.8047e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00054: val_loss did not improve from 0.00013
# Epoch 55/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8777e-04 - mse: 3.7555e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00055: val_loss did not improve from 0.00013
# Epoch 56/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9491e-04 - mse: 3.8982e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00056: val_loss did not improve from 0.00013
# Epoch 57/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8316e-04 - mse: 3.6632e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00057: val_loss did not improve from 0.00013
# Epoch 58/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8337e-04 - mse: 3.6673e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00058: val_loss did not improve from 0.00013
# Epoch 59/100
# 6/6 [==============================] - 0s 18ms/step - loss: 1.9082e-04 - mse: 3.8163e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00059: val_loss did not improve from 0.00013
# Epoch 60/100
# 6/6 [==============================] - 0s 17ms/step - loss: 2.0187e-04 - mse: 4.0374e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00060: val_loss did not improve from 0.00013
# Epoch 61/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8273e-04 - mse: 3.6546e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00061: val_loss did not improve from 0.00013
# Epoch 62/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8725e-04 - mse: 3.7450e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00062: val_loss did not improve from 0.00013
# Epoch 63/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9136e-04 - mse: 3.8272e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00063: val_loss did not improve from 0.00013
# Epoch 64/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8458e-04 - mse: 3.6916e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00064: val_loss did not improve from 0.00013
# Epoch 65/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8022e-04 - mse: 3.6044e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00065: val_loss did not improve from 0.00013
# Epoch 66/100
# 6/6 [==============================] - 0s 18ms/step - loss: 2.0800e-04 - mse: 4.1600e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00066: val_loss did not improve from 0.00013
# Epoch 67/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8832e-04 - mse: 3.7663e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00067: val_loss did not improve from 0.00013
# Epoch 68/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.9451e-04 - mse: 3.8903e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00068: val_loss did not improve from 0.00013
# Epoch 69/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9660e-04 - mse: 3.9319e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00069: val_loss did not improve from 0.00013
# Epoch 70/100
# 6/6 [==============================] - 0s 20ms/step - loss: 1.8909e-04 - mse: 3.7819e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00070: val_loss did not improve from 0.00013
# Epoch 71/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8418e-04 - mse: 3.6836e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00071: val_loss did not improve from 0.00013
# Epoch 72/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9361e-04 - mse: 3.8722e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00072: val_loss did not improve from 0.00013
# Epoch 73/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9451e-04 - mse: 3.8902e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00073: val_loss did not improve from 0.00013
# Epoch 74/100
# 6/6 [==============================] - 0s 16ms/step - loss: 2.0450e-04 - mse: 4.0900e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00074: val_loss did not improve from 0.00013
# Epoch 75/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9547e-04 - mse: 3.9093e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00075: val_loss did not improve from 0.00013
# Epoch 76/100
# 6/6 [==============================] - 0s 16ms/step - loss: 2.0174e-04 - mse: 4.0347e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00076: val_loss did not improve from 0.00013
# Epoch 77/100
# 6/6 [==============================] - 0s 18ms/step - loss: 1.8366e-04 - mse: 3.6731e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00077: val_loss did not improve from 0.00013
# Epoch 78/100
# 6/6 [==============================] - 0s 18ms/step - loss: 1.9690e-04 - mse: 3.9381e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00078: val_loss did not improve from 0.00013
# Epoch 79/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9650e-04 - mse: 3.9301e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00079: val_loss did not improve from 0.00013
# Epoch 80/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8451e-04 - mse: 3.6902e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00080: val_loss did not improve from 0.00013
# Epoch 81/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.9149e-04 - mse: 3.8297e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00081: val_loss did not improve from 0.00013
# Epoch 82/100
# 6/6 [==============================] - 0s 19ms/step - loss: 2.0656e-04 - mse: 4.1312e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00082: val_loss did not improve from 0.00013
# Epoch 83/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.9679e-04 - mse: 3.9359e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00083: val_loss did not improve from 0.00013
# Epoch 84/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9145e-04 - mse: 3.8291e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00084: val_loss did not improve from 0.00013
# Epoch 85/100
# 6/6 [==============================] - 0s 17ms/step - loss: 2.0783e-04 - mse: 4.1567e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00085: val_loss did not improve from 0.00013
# Epoch 86/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9339e-04 - mse: 3.8679e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00086: val_loss did not improve from 0.00013
# Epoch 87/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9225e-04 - mse: 3.8449e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00087: val_loss did not improve from 0.00013
# Epoch 88/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.8718e-04 - mse: 3.7435e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00088: val_loss did not improve from 0.00013
# Epoch 89/100
# 6/6 [==============================] - 0s 18ms/step - loss: 2.0306e-04 - mse: 4.0611e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00089: val_loss did not improve from 0.00013
# Epoch 90/100
# 6/6 [==============================] - 0s 19ms/step - loss: 1.9584e-04 - mse: 3.9168e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00090: val_loss did not improve from 0.00013
# Epoch 91/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8179e-04 - mse: 3.6358e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00091: val_loss did not improve from 0.00013
# Epoch 92/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9252e-04 - mse: 3.8504e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00092: val_loss did not improve from 0.00013
# Epoch 93/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8453e-04 - mse: 3.6905e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00093: val_loss did not improve from 0.00013
# Epoch 94/100
# 6/6 [==============================] - 0s 18ms/step - loss: 1.9614e-04 - mse: 3.9229e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00094: val_loss did not improve from 0.00013
# Epoch 95/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.7993e-04 - mse: 3.5985e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00095: val_loss did not improve from 0.00013
# Epoch 96/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8335e-04 - mse: 3.6669e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00096: val_loss did not improve from 0.00013
# Epoch 97/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.8264e-04 - mse: 3.6528e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00097: val_loss did not improve from 0.00013
# Epoch 98/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.9193e-04 - mse: 3.8385e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00098: val_loss did not improve from 0.00013
# Epoch 99/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.8509e-04 - mse: 3.7019e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00099: val_loss did not improve from 0.00013
# Epoch 100/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.9589e-04 - mse: 3.9177e-04 - val_loss: 1.3819e-04 - val_mse: 2.7638e-04
#
# Epoch 00100: val_loss did not improve from 0.00013

# %%
pred = model.predict(x_test)

fig = plt.figure(facecolor="white", figsize=(20, 10))

ax = fig.add_subplot(111)
ax.plot(y_test, label="True",marker='*')
ax.plot(pred, label="Prediction",marker='o')
ax.legend()
plt.show()

# %%
def load_price_info(code,interval,count=200):
    df = pyupbit.get_ohlcv(code,interval,count)
    df['Time']=0
    time_idx = list(df.index)
    for time,idx in enumerate(time_idx):
        df['Time'][idx]=str(idx)
    return df

def input_reshape(data):
    data=np.array(data)
    return np.reshape(data, (data.shape[0], data.shape[1], 1))

# %%
df = load_price_info(code,interval=INTERVAL,count=200)

current_prices = df["close"].values

time_len = 5

new_data=[]
future_price=[]
for index in range(len(current_prices) - sequence_length):
    new_data.append(current_prices[index : index + sequence_length-1])
for i in range(time_len):
    windowed_current_prices = normalize_windows([new_data[-1-i]])
    windowed_current_prices = input_reshape(windowed_current_prices)
    pred = model.predict(windowed_current_prices[-time_len:])
    origin_price=(pred+1)*new_data[-1-i][0]

    future_price.append(origin_price[0][0])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
future=(future_price[0]-current_prices[-1])/current_prices[-1]
now=(future_price[1]-current_prices[-2])/current_prices[-2]
past=(future_price[2]-current_prices[-3])/current_prices[-3]

print('future : ',future)
print('now : ', now)
print('past : ',past)
# Out:
# future :  0.004155492356914326
# now :  0.0041259657910161455
# past :  0.002836949783013019

# %%
import seaborn as sns
fig = plt.figure(facecolor="white", figsize=(20, 10))

ax = fig.add_subplot(111)
ax.plot([0,future_price[2],future_price[1],future_price[0]], label="Prediction",marker='*')
ax.plot([current_prices[-3],current_prices[-2],current_prices[-1]], label="True",marker='o')
sns.lineplot(x=['n-2','n-1','now','predicted'], ax=ax)
ax.legend()
plt.show()
print([current_prices[-3],current_prices[-2],current_prices[-1]])
# Out:
# [56455000.0, 56301000.0, 56260000.0]
